# %% [markdown]
# ## some important classification metrics

# %% [markdown]
# ![temp1.png](attachment:temp1.png)

# %% [markdown]
# ![temp2.png](attachment:temp2.png)

# %% [markdown]
# ![temp3.png](attachment:temp3.png)

# %% [markdown]
# ![temp4.png](attachment:temp4.png)

# %% [markdown]
# ![temp5.png](attachment:temp5.png)

# %%
## code to show the use of above metrics

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

y_true = [0, 1, 1, 0, 1, 0, 0, 1, 1, 1]
y_pred = [0, 1, 1, 0, 1, 1, 0, 0, 0, 1]

print("confusion matrix:\n", confusion_matrix(y_true, y_pred))
print("Accuracy:", accuracy_score(y_true, y_pred))
print("Precision:", precision_score(y_true, y_pred))
print("Recall:", recall_score(y_true, y_pred))
print("F1 Score:", f1_score(y_true, y_pred))
# Out:
# confusion matrix:
#  [[3 1]
#  [2 4]]
# Accuracy: 0.7
# Precision: 0.8
# Recall: 0.6666666666666666
# F1 Score: 0.7272727272727273

# %%
## another code to show the use of metrics

## importing necessary modules and libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

## load the iris dataset
iris = load_iris()
x = iris.data
y = iris.target

## split into train and test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=11)

## train the model
model = RandomForestClassifier(random_state=11)
model.fit(x_train, y_train)

## predict 
y_pred = model.predict(x_test)

# Evaluation Metrics
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision (macro):", precision_score(y_test, y_pred, average='macro'))
print("Recall (macro):", recall_score(y_test, y_pred, average='macro'))
print("F1 Score (macro):", f1_score(y_test, y_pred, average='macro'))

# %% [markdown]
# 'macro' calculates the unweighted average of metrics for all classes, treating them equally.
#
# Other options:
#
# 'micro': global metrics by counting total TP, FP, FN
#
# 'weighted': takes class imbalance into account
