# %% [markdown]
# ### building,compiling,training and evaluating the model using keras and inbuilt functions

# %%
## Importing libraries and modules
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import numpy as np

## loading and preprocessing 
data = load_iris()
X = data.data.astype(np.float32)  # Convert features to float32 for TensorFlow compatibility
y = data.target.reshape(-1, 1)    # Reshape labels to a column vector

# One-hot encode the labels (required for categorical crossentropy loss)
encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y).astype(np.float32)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Define a simple feedforward neural network
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, activation="relu", input_shape=(4,)),     # Layer 1: W1 shape (4,10), b1 shape (10,)    
    tf.keras.layers.Dense(8, activation="relu"),                   # Layer 2: W2 shape (10,8), b2 shape (8,) 
    tf.keras.layers.Dense(3, activation="softmax")                # Output Layer: W3 shape (8,3), b3 shape (3,)
])

# Compile the model with optimizer, loss, and metrics
model.compile(optimizer="adam",
              loss="categorical_crossentropy",      # Use categorical crossentropy for multi-class classification
              metrics = ["accuracy"])               # # Track accuracy during training


# Train the model on the training data
model.fit(X_train, y_train,
          epochs=50,             # Number of training iterations
          batch_size=8,          # Number of samples per gradient update
          validation_split=0.1)  # Use 10% of the training data for validation

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test accuracy:", test_acc)
print("Test loss:",test_loss)
# Out:
# c:\Users\anish\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.3432 - loss: 1.3995 - val_accuracy: 0.4167 - val_loss: 1.1566
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3247 - loss: 1.2340 - val_accuracy: 0.4167 - val_loss: 1.0280
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2736 - loss: 1.2277 - val_accuracy: 0.4167 - val_loss: 0.9809
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3659 - loss: 1.0360 - val_accuracy: 0.4167 - val_loss: 0.9566
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2861 - loss: 1.0685 - val_accuracy: 0.4167 - val_loss: 0.9303
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3179 - loss: 1.0094 - val_accuracy: 0.8333 - val_loss: 0.9100
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4622 - loss: 1.0036 - val_accuracy: 0.8333 - val_loss: 0.9023
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4827 - loss: 0.9460 - val_accuracy: 0.7500 - val_loss: 0.8892
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4122 - loss: 0.9654 - val_accuracy: 0.8333 - val_loss: 0.8818
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5757 - loss: 0.9211 - val_accuracy: 0.7500 - val_loss: 0.8628
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4688 - loss: 0.9043 - val_accuracy: 0.5833 - val_loss: 0.8479
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6352 - loss: 0.8829 - val_accuracy: 0.6667 - val_loss: 0.8322
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7552 - loss: 0.8622 - val_accuracy: 0.9167 - val_loss: 0.8124
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7367 - loss: 0.8447 - val_accuracy: 1.0000 - val_loss: 0.7861
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8507 - loss: 0.7858 - val_accuracy: 0.7500 - val_loss: 0.7637
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7922 - loss: 0.7342 - val_accuracy: 0.8333 - val_loss: 0.7281
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7974 - loss: 0.6989 - val_accuracy: 1.0000 - val_loss: 0.6894
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9251 - loss: 0.6604 - val_accuracy: 1.0000 - val_loss: 0.6690
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8643 - loss: 0.6214 - val_accuracy: 0.9167 - val_loss: 0.6327
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8551 - loss: 0.5763 - val_accuracy: 1.0000 - val_loss: 0.6080
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9560 - loss: 0.5725 - val_accuracy: 1.0000 - val_loss: 0.5798
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9132 - loss: 0.5434 - val_accuracy: 1.0000 - val_loss: 0.5576
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8929 - loss: 0.5094 - val_accuracy: 1.0000 - val_loss: 0.5462
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8876 - loss: 0.4837 - val_accuracy: 1.0000 - val_loss: 0.5233
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8863 - loss: 0.5164 - val_accuracy: 1.0000 - val_loss: 0.5018
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9498 - loss: 0.4375 - val_accuracy: 1.0000 - val_loss: 0.4878
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8903 - loss: 0.4635 - val_accuracy: 1.0000 - val_loss: 0.4717
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9209 - loss: 0.4293 - val_accuracy: 1.0000 - val_loss: 0.4566
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8929 - loss: 0.4283 - val_accuracy: 1.0000 - val_loss: 0.4452
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9284 - loss: 0.4029 - val_accuracy: 1.0000 - val_loss: 0.4334
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9367 - loss: 0.4071 - val_accuracy: 1.0000 - val_loss: 0.4221
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9094 - loss: 0.4190 - val_accuracy: 1.0000 - val_loss: 0.4115
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8990 - loss: 0.3875 - val_accuracy: 1.0000 - val_loss: 0.4037
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9205 - loss: 0.3668 - val_accuracy: 1.0000 - val_loss: 0.3907
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8808 - loss: 0.3753 - val_accuracy: 1.0000 - val_loss: 0.3798
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9331 - loss: 0.3500 - val_accuracy: 1.0000 - val_loss: 0.3772
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9108 - loss: 0.3474 - val_accuracy: 1.0000 - val_loss: 0.3612
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9158 - loss: 0.3460 - val_accuracy: 1.0000 - val_loss: 0.3564
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9331 - loss: 0.3160 - val_accuracy: 1.0000 - val_loss: 0.3467
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9198 - loss: 0.3450 - val_accuracy: 1.0000 - val_loss: 0.3359
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9585 - loss: 0.2891 - val_accuracy: 1.0000 - val_loss: 0.3275
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9270 - loss: 0.3212 - val_accuracy: 1.0000 - val_loss: 0.3225
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9369 - loss: 0.3206 - val_accuracy: 1.0000 - val_loss: 0.3116
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9232 - loss: 0.3376 - val_accuracy: 1.0000 - val_loss: 0.3018
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9464 - loss: 0.2753 - val_accuracy: 1.0000 - val_loss: 0.2963
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9538 - loss: 0.2911 - val_accuracy: 1.0000 - val_loss: 0.2884
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9693 - loss: 0.2714 - val_accuracy: 1.0000 - val_loss: 0.2806
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9485 - loss: 0.2480 - val_accuracy: 1.0000 - val_loss: 0.2746
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9522 - loss: 0.2815 - val_accuracy: 1.0000 - val_loss: 0.2682
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9527 - loss: 0.2733 - val_accuracy: 1.0000 - val_loss: 0.2608
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2322
# Test accuracy: 1.0
# Test loss: 0.23223455250263214

# %% [markdown]
# ### Implementation of simple neural network from scratch using tensorflow without keras

# %%
## Importing libraries and modules
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import numpy as np

## loading and preprocessing 
data = load_iris()
X = data.data.astype(np.float32)  # Convert features to float32 for TensorFlow compatibility
y = data.target.reshape(-1, 1)    # Reshape labels to a column vector

# One-hot encode the labels (required for categorical crossentropy loss)
encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y).astype(np.float32)

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

## defining the weight manually
W1 = tf.Variable(tf.random.normal([1, 10]))
# Layer 1: Input (4 features) → Hidden Layer 1 (10 neurons)
W1 = tf.Variable(tf.random.normal([4, 10]))
b1 = tf.Variable(tf.zeros([10]))

# Layer 2: Hidden Layer 1 (10 neurons) → Hidden Layer 2 (6 neurons)
W2 = tf.Variable(tf.random.normal([10, 6]))
b2 = tf.Variable(tf.zeros([6]))

# Layer 3: Hidden Layer 2 (6 neurons) → Output Layer (3 classes)
W3 = tf.Variable(tf.random.normal([6, 3]))
b3 = tf.Variable(tf.zeros([3]))

## define the forward pass function
def forward(X):
    h1 = tf.nn.relu(tf.matmul(X, W1) + b1)
    h2 = tf.nn.relu(tf.matmul(h1, W2) + b2)
    output = tf.nn.softmax(tf.matmul(h2, W3) + b3)
    return output

# define the loss function
def loss_fn(y_pred, y_true):
    return tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_true, y_pred))

# define the optimizer
optimizer = tf.optimizers.Adam()

# Training loop for 50 epochs
for epoch in range(50):
    with tf.GradientTape as tape:
        predictions = forward(X_train)     # forward pass on training data
        loss = loss_fn(predictions, y_train)   # compute loss
    grads = tape.gradient(loss, [W1, b1, W2, b2, W3, b3])   # compute gradients
    optimizer.apply_gradients(zip(grads, [W1, b1, W2, b2, W3, b3]))  # update weights
