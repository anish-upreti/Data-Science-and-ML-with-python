# %% [markdown]
# ## KMeans Clustering

# %%
## For 2D data points

## importing libraries and modules
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

## manually create a numpy array with 2D data points (x, y)
X = np.array([
    [1.0, 2.0],
    [1.5, 1.8],
    [5.0, 8.0],
    [8.0, 8.0],
    [1.0, 0.6],
    [9.0, 11.0],
    [8.0, 2.0],
    [10.0, 2.0],
    [9.0, 3.0],
    [2.0, 3.0]
    ])

## apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=11)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# Predict which cluster each point belongs to
y_kmeans = kmeans.predict(X)  # This assigns each point to a cluster label (0, 1, or 2).
                            # y_kmeans = kmeans.predict(X) and kmeans.labels_ give you the same result after fitting, but for different purposes.
# get the cluster centers
centers = kmeans.cluster_centers_

print("y_kmeans: ", y_kmeans)
print("Centers: \n", centers)

## visualize the results
plt.scatter(X[:,0], X[:, 1], c=y_kmeans, cmap = "viridis", s = 100)  # X[:, 0] = x-values, X[:, 1] = y-values.
                                                                    # c=y_kmeans: colors the points based on their cluster assignment.
plt.scatter(centers[:, 0], centers[:, 1], c="red", s = 200, alpha=0.75, marker="X")

plt.title("K-Means Clustering on Custom NumPy Data")

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# c:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# y_kmeans:  [0 0 1 1 0 1 2 2 2 0]
# Centers:
#  [[1.375      1.85      ]
#  [7.33333333 9.        ]
#  [9.         2.33333333]]

# %%
## For 1D  data

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# 1D data (wrapped as 2D array for sklearn)
X = np.array([[150], [155], [160], [162], [165], [170], [172], [180], [185], [190]])

# Apply KMeans with 3 clusters
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)

# Predicted cluster labels and centers
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Plotting 1D points along x-axis, setting y=0
plt.scatter(X[:, 0], np.zeros_like(X), c=labels, cmap='viridis', s=100)
plt.scatter(centers[:, 0], np.zeros_like(centers), c='red', s=200, marker='X', label='Centers')

plt.title("K-Means Clustering on 1D Data")
plt.xlabel("Value")
# plt.yticks([])  # Hide y-axis
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\anish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
## For 3D data
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Create synthetic 3D data (x, y, z)
X = np.array([
    [1, 2, 1],
    [1.5, 1.8, 1.2],
    [5, 8, 6],
    [8, 8, 7],
    [1, 0.6, 0.5],
    [9, 11, 10],
    [8, 2, 2],
    [10, 2, 3],
    [9, 3, 3.5],
    [2, 3, 1.5]
])

# apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# plotting in 3D
fig = plt.figure(figsize=(8, 6))
